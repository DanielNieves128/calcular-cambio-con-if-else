# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielNieves128/calcular-cambio-con-if-else/blob/main/Elprofe_Act_12_Cambio_Daniel_Nieves_1343.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Daniel Nieves NL = 41 Fecha 26/03/26
# ### calculando el cambio usando if else
# ### mirar diagrama de flujo
# ![cambio3.jpg](https://raw.githubusercontent.com/DanielNieves128/calcular-cambio-con-if-else/refs/heads/main/cambio3.jpg)
#
# ## las variables
# 1. CP --> costo del producto
# 2. CD --> cantidad de dinero
# 3. cambio
#
# ## formulas
# $Cambio = CD - CP$
#
# ## Diagrama de flujo LucidChart
# ![](https://raw.githubusercontent.com/DanielNieves128/calcular-cambio-con-if-else/refs/heads/main/diagramacambio.PNG)

# %%
# calculando el cambio usando if else
# datos de entrada CP, CD
# mostrar cambio si es falso
# si es verdadero mostrar No alcanza
CP = float(input("Ingrese el costo del producto: "))
CD = float(input("Ingrese la cantidad de dinero: "))
if CP > CD:
  print("No alcanza")
else:
  cambio = CD - CP
  print(" el cambio es: ", cambio)
print("Fin del programa")
print("programa realizado por Daniel Nieves NL = 41")
# Out:
# Ingrese el costo del producto: 300
# Ingrese la cantidad de dinero: 400
#  el cambio es:  100.0
# Fin del programa
# programa realizado por Daniel Nieves NL = 41

# %%
# para cuando es falso (no)
# calculando el cambio usando if else
# datos de entrada CP, CD
# mostrar cambio si es falso
# si es verdadero mostrar No alcanza
CP = float(input("Ingrese el costo del producto: "))
CD = float(input("Ingrese la cantidad de dinero: "))
if CP > CD:
  print("No alcanza")
else:
  cambio = CD - CP
  print(" el cambio es: ", cambio)
print("Fin del programa")
print("programa realizado por Daniel Nieves NL = 41")
# Out:
# Ingrese el costo del producto: 250
# Ingrese la cantidad de dinero: 300
#  el cambio es:  50.0
# Fin del programa
# programa realizado por Daniel Nieves NL = 41

# %% [markdown]
# ## Relacion entre codigo y diagrama de flujo
# ![](https://raw.githubusercontent.com/DanielNieves128/calcular-cambio-con-if-else/refs/heads/main/TLDraw%20codigo%20DF.png)
